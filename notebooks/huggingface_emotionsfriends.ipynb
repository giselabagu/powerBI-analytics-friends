# %%
# pip install transformers torch 
# pip install sentencepiece

# %%
import pandas as pd
from transformers import pipeline

from tqdm import tqdm

pd.set_option('display.max_colwidth', None)

# %%
tqdm.pandas(desc="Pensando")

# %%
df = pd.read_csv("fils/friends_quotes.csv")
df.head()
# Out:
#      author  episode_number           episode_title  \
# 0    Monica             1.0  Monica Gets A Roommate
# 1      Joey             1.0  Monica Gets A Roommate
# 2  Chandler             1.0  Monica Gets A Roommate
# 3    Phoebe             1.0  Monica Gets A Roommate
# 4    Phoebe             1.0  Monica Gets A Roommate
#
#                                                                               quote  \
# 0                          There's nothing to tell! He's just some guy I work with!
# 1  C'mon, you're going out with the guy! There's gotta be something wrong with him!
# 2          All right Joey, be nice. So does he have a hump? A hump and a hairpiece?
# 3                                                          Wait, does he eat chalk?
# 4   Just, 'cause, I don't want her to go through what I went through with Carl- oh!
#
#    quote_order  season
# 0          0.0     1.0
# 1          1.0     1.0
# 2          2.0     1.0
# 3          3.0     1.0
# 4          4.0     1.0

# %%
emotion_analyzer = pipeline(
    "text-classification",
    model="j-hartmann/emotion-english-distilroberta-base",
    return_all_scores=True
)
# Out:
# Device set to use cpu

# %%
def get_dominant_emotion(text):
    scores = emotion_analyzer(text)[0]
    return max(scores, key=lambda x: x["score"])["label"]

# %%
# df["emotion"] = df["quote"].apply(get_dominant_emotion)

# df[["author", "quote", "emotion"]].head()
# Out:
#      author  \
# 0    Monica
# 1      Joey
# 2  Chandler
# 3    Phoebe
# 4    Phoebe
#
#                                                                               quote  \
# 0                          There's nothing to tell! He's just some guy I work with!
# 1  C'mon, you're going out with the guy! There's gotta be something wrong with him!
# 2          All right Joey, be nice. So does he have a hump? A hump and a hairpiece?
# 3                                                          Wait, does he eat chalk?
# 4   Just, 'cause, I don't want her to go through what I went through with Carl- oh!
#
#    emotion
# 0  neutral
# 1    anger
# 2  neutral
# 3  neutral
# 4    anger

# %%
# df.to_csv('files/df_emotionfriends.csv', index=False)
# index=False para que no se guarde la columna de índices.

# %% [markdown]
# Si tenemos muchas filas, mejor usar esta opción (más rápida):

# %%
def batch_emotions(texts, batch_size=32):
    results = []
    for i in range(0, len(texts), batch_size):
        batch = texts[i:i+batch_size]
        outputs = emotion_analyzer(batch)
        for scores in outputs:
            results.append(max(scores, key=lambda x: x["score"])["label"])
    return results

df["emotion"] = batch_emotions(df["quote"].tolist())

# %%
df_emo = pd.read_csv("fils/df_emotionfriends.csv")
df_emo.head()
# Out:
#      author  episode_number           episode_title  \
# 0    Monica             1.0  Monica Gets A Roommate
# 1      Joey             1.0  Monica Gets A Roommate
# 2  Chandler             1.0  Monica Gets A Roommate
# 3    Phoebe             1.0  Monica Gets A Roommate
# 4    Phoebe             1.0  Monica Gets A Roommate
#
#                                                                               quote  \
# 0                          There's nothing to tell! He's just some guy I work with!
# 1  C'mon, you're going out with the guy! There's gotta be something wrong with him!
# 2          All right Joey, be nice. So does he have a hump? A hump and a hairpiece?
# 3                                                          Wait, does he eat chalk?
# 4   Just, 'cause, I don't want her to go through what I went through with Carl- oh!
#
#    quote_order  season  emotion
# 0          0.0     1.0  neutral
# 1          1.0     1.0    anger
# 2          2.0     1.0  neutral
# 3          3.0     1.0  neutral
# 4          4.0     1.0    anger

# %%
df_emo['emotion'].value_counts()
# Out:
# emotion
# neutral     19080
# surprise    14974
# anger        8487
# joy          7874
# disgust      5524
# sadness      2342
# fear         2010
# Name: count, dtype: int64

# %%
main_characters = [
    "Monica", "Joey", "Chandler",
    "Phoebe", "Ross", "Rachel"]

df_clean = df_emo[df_emo["author"].isin(main_characters)].copy()

# %%
df_clean.to_csv('fils/df_emotionfriends_clean.csv', index=False)
# index=False para que no se guarde la columna de índices.

# %%
df_clean["author"].value_counts()
# Out:
# author
# Rachel      8318
# Ross        8088
# Monica      7516
# Chandler    7488
# Joey        7373
# Phoebe      6699
# Name: count, dtype: int64

# %%
emotion_by_character = (
    df_clean
    .groupby("author")["emotion"]
    .value_counts(normalize=True)
    .unstack()
    .fillna(0))

emotion_by_character
# Out:
# emotion      anger   disgust      fear       joy   neutral   sadness  surprise
# author
# Chandler  0.155048  0.093884  0.039263  0.124866  0.312366  0.036993  0.237580
# Joey      0.169131  0.098603  0.034721  0.149193  0.265021  0.033094  0.250237
# Monica    0.164582  0.086615  0.024880  0.125200  0.284194  0.036855  0.277674
# Phoebe    0.149873  0.106583  0.034483  0.138976  0.283774  0.036722  0.249589
# Rachel    0.149195  0.086559  0.036187  0.130921  0.270738  0.042077  0.284323
# Ross      0.147255  0.086672  0.040183  0.131677  0.301187  0.037710  0.255317

# %%
emotion_by_season = (
    df_clean.groupby("season")["emotion"]
      .value_counts(normalize=True)
      .unstack()
      .fillna(0))

emotion_by_season
# Out:
# emotion     anger   disgust      fear       joy   neutral   sadness  surprise
# season
# 1.0      0.109000  0.094801  0.021188  0.082350  0.395369  0.038008  0.259284
# 2.0      0.110795  0.122159  0.019886  0.068182  0.414773  0.034091  0.230114
# 3.0      0.143403  0.109414  0.042582  0.117434  0.316975  0.040099  0.230094
# 4.0      0.175523  0.095397  0.040377  0.146862  0.261506  0.034100  0.246234
# 5.0      0.168389  0.096035  0.023868  0.151475  0.262169  0.038527  0.259538
# 6.0      0.185929  0.097848  0.038886  0.154458  0.238018  0.031470  0.253391
# 7.0      0.187695  0.078557  0.044497  0.139352  0.239700  0.032778  0.277422
# 8.0      0.165105  0.096214  0.053084  0.136612  0.250781  0.032787  0.265418
# 9.0      0.131018  0.082020  0.025991  0.130166  0.301236  0.048360  0.281210
# 10.0     0.123241  0.079664  0.021562  0.138675  0.325238  0.042442  0.269178

# %%
df_clean[df_clean["emotion"] == "neutral"]
# Out:
#          author  episode_number              episode_title  \
# 0        Monica             1.0     Monica Gets A Roommate
# 2      Chandler             1.0     Monica Gets A Roommate
# 3        Phoebe             1.0     Monica Gets A Roommate
# 5        Monica             1.0     Monica Gets A Roommate
# 6      Chandler             1.0     Monica Gets A Roommate
# ...         ...             ...                        ...
# 60284      Joey            17.0  The Last One, Part I & II
# 60286  Chandler            17.0  The Last One, Part I & II
# 60288    Monica            17.0  The Last One, Part I & II
# 60289    Rachel            17.0  The Last One, Part I & II
# 60290  Chandler            17.0  The Last One, Part I & II
#
#                                                                                                                quote  \
# 0                                                           There's nothing to tell! He's just some guy I work with!
# 2                                           All right Joey, be nice. So does he have a hump? A hump and a hairpiece?
# 3                                                                                           Wait, does he eat chalk?
# 5      Okay, everybody relax. This is not even a date. It's just two people going out to dinner and- not having sex.
# 6                                                                                          Sounds like a date to me.
# ...                                                                                                              ...
# 60284                                                                                              Yeah. I guess so.
# 60286                                                                                        Oh, it's gonna be okay.
# 60288                                                                                              We got some time.
# 60289                                                                               Okay, should we get some coffee?
# 60290                                                                                                   Sure. Where?
#
#        quote_order  season  emotion
# 0              0.0     1.0  neutral
# 2              2.0     1.0  neutral
# 3              3.0     1.0  neutral
# 5              5.0     1.0  neutral
# 6              6.0     1.0  neutral
# ...            ...     ...      ...
# 60284        579.0    10.0  neutral
# 60286        581.0    10.0  neutral
# 60288        583.0    10.0  neutral
# 60289        584.0    10.0  neutral
# 60290        585.0    10.0  neutral
#
# [13018 rows x 7 columns]

# %%
df_clean[df_clean["emotion"] == "fear"]
# Out:
#          author  episode_number              episode_title  \
# 12         Joey             1.0     Monica Gets A Roommate
# 73     Chandler             1.0     Monica Gets A Roommate
# 86       Monica             1.0     Monica Gets A Roommate
# 141        Ross             1.0     Monica Gets A Roommate
# 256    Chandler             1.0     Monica Gets A Roommate
# ...         ...             ...                        ...
# 60048  Chandler            17.0  The Last One, Part I & II
# 60128      Joey            17.0  The Last One, Part I & II
# 60192  Chandler            17.0  The Last One, Part I & II
# 60214    Phoebe            17.0  The Last One, Part I & II
# 60261    Rachel            17.0  The Last One, Part I & II
#
#                                                                                                                                                                                                            quote  \
# 12                                                                                                                                                                                         Never had that dream.
# 73                                                                                                                                                            Please don't do that again, it's a horrible sound.
# 86                                                                                                                                                                                           (horrified) Really?
# 141    You know what the scariest part is? What if there's only one woman for everybody, y'know? I mean what if you get one woman- and that's it? Unfortunately in my case, there was only one woman- for her...
# 256                                                                                                 (as Rachel is cutting up her cards) Y'know, if you listen closely, you can hear a thousand retailers scream.
# ...                                                                                                                                                                                                          ...
# 60048                                                                                                                                                                          Oh, don't worry, we'll find them.
# 60128                                                                                                                                         (yelling) Don't worry, you guys, we're gonna get you out of there.
# 60192                                                                                                          Aww, we were worried about you! Hm. I guess I better get used to things crapping in my hand, huh?
# 60214                                                                                                                                                                                       (screaming) RACHEL!!
# 60261                                                                                                                                                                                       I got off the plane.
#
#        quote_order  season emotion
# 12            12.0     1.0    fear
# 73            73.0     1.0    fear
# 86            86.0     1.0    fear
# 141          142.0     1.0    fear
# 256          258.0     1.0    fear
# ...            ...     ...     ...
# 60048        343.0    10.0    fear
# 60128        423.0    10.0    fear
# 60192        487.0    10.0    fear
# 60214        509.0    10.0    fear
# 60261        556.0    10.0    fear
#
# [1594 rows x 7 columns]

# %%
df_clean[df_clean["emotion"] == "joy"]
# Out:
#          author  episode_number              episode_title  \
# 29         Ross             1.0     Monica Gets A Roommate
# 39         Joey             1.0     Monica Gets A Roommate
# 46       Rachel             1.0     Monica Gets A Roommate
# 66       Phoebe             1.0     Monica Gets A Roommate
# 68       Phoebe             1.0     Monica Gets A Roommate
# ...         ...             ...                        ...
# 60226      Ross            17.0  The Last One, Part I & II
# 60242      Joey            17.0  The Last One, Part I & II
# 60243      Joey            17.0  The Last One, Part I & II
# 60263    Rachel            17.0  The Last One, Part I & II
# 60275  Chandler            17.0  The Last One, Part I & II
#
#                                                                                                                                                                                                                            quote  \
# 29                                                                                                                                                         I'll be fine, alright? Really, everyone. I hope she'll be very happy.
# 39                                                                                                                                                                        Strip joint! C'mon, you're single! Have some hormones!
# 46                                                                                                                                                                                                                     Hi, sure!
# 66     (sings) Raindrops on roses and rabbits and kittens, (Rachel and Monica turn to look at her.) bluebells and sleighbells and- something with mittens... La la la la...something and noodles with string. These are a few...
# 68                                                                                                                                                     (grins and walks to the kitchen and says to Chandler and Joey.) I helped!
# ...                                                                                                                                                                                                                          ...
# 60226                                                                                                                                                                               Hey, hey. I know you love me. I know you do.
# 60242                                                                                                                                                                                                                I love you!
# 60243                                                                                                                                                                                                                       Hey!
# 60263                                                                                                                                                                                                             I do love you.
# 60275                          (to his children) Look around, you guys. This was your first home. And it was a happy place, filled with love and laughter. But more important, because of rent control, it was a friggin' steal!
#
#        quote_order  season emotion
# 29            29.0     1.0     joy
# 39            39.0     1.0     joy
# 46            46.0     1.0     joy
# 66            66.0     1.0     joy
# 68            68.0     1.0     joy
# ...            ...     ...     ...
# 60226        521.0    10.0     joy
# 60242        537.0    10.0     joy
# 60243        538.0    10.0     joy
# 60263        558.0    10.0     joy
# 60275        570.0    10.0     joy
#
# [6061 rows x 7 columns]

# %%
df_clean[df_clean["emotion"] == "anger"]
# Out:
#        author  episode_number              episode_title  \
# 1        Joey             1.0     Monica Gets A Roommate
# 4      Phoebe             1.0     Monica Gets A Roommate
# 18       Joey             1.0     Monica Gets A Roommate
# 19     Monica             1.0     Monica Gets A Roommate
# 27       Ross             1.0     Monica Gets A Roommate
# ...       ...             ...                        ...
# 60257  Rachel            17.0  The Last One, Part I & II
# 60258    Ross            17.0  The Last One, Part I & II
# 60266    Ross            17.0  The Last One, Part I & II
# 60267  Rachel            17.0  The Last One, Part I & II
# 60269    Ross            17.0  The Last One, Part I & II
#
#                                                                                   quote  \
# 1      C'mon, you're going out with the guy! There's gotta be something wrong with him!
# 4       Just, 'cause, I don't want her to go through what I went through with Carl- oh!
# 18                                            This guy says hello, I wanna kill myself.
# 19                                                               Are you okay, sweetie?
# 27            No, no don't! Stop cleansing my aura! No, just leave my aura alone, okay?
# ...                                                                                 ...
# 60257                (on the answering machine) Oh, please, miss, you don't understand!
# 60258                                                                Try to understand!
# 60266                               Me neither, okay? We are - we're done being stupid.
# 60267                                            Okay. You and me, alright? This is it.
# 60269                                                             Don't make jokes now.
#
#        quote_order  season emotion
# 1              1.0     1.0   anger
# 4              4.0     1.0   anger
# 18            18.0     1.0   anger
# 19            19.0     1.0   anger
# 27            27.0     1.0   anger
# ...            ...     ...     ...
# 60257        552.0    10.0   anger
# 60258        553.0    10.0   anger
# 60266        561.0    10.0   anger
# 60267        562.0    10.0   anger
# 60269        564.0    10.0   anger
#
# [7081 rows x 7 columns]

# %%
df_clean[df_clean["emotion"] == "disgust"]
# Out:
#          author  episode_number              episode_title  \
# 16     Chandler             1.0     Monica Gets A Roommate
# 20         Ross             1.0     Monica Gets A Roommate
# 28       Phoebe             1.0     Monica Gets A Roommate
# 34     Chandler             1.0     Monica Gets A Roommate
# 51       Rachel             1.0     Monica Gets A Roommate
# ...         ...             ...                        ...
# 60249    Rachel            17.0  The Last One, Part I & II
# 60259    Rachel            17.0  The Last One, Part I & II
# 60265    Rachel            17.0  The Last One, Part I & II
# 60271    Monica            17.0  The Last One, Part I & II
# 60285    Monica            17.0  The Last One, Part I & II
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  quote  \
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                     Finally, I figure I'd better answer it, and it turns out it's my mother, which is very-very weird, because- she never calls me!
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                I just feel like someone reached down my throat, grabbed my small intestine, pulled it out of my mouth and tied it around my neck...
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Fine! Be murky!
# 34                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Sometimes I wish I was a lesbian... (They all stare at him.) Did I say that out loud?
# 51                                                                                                                                                                                                                                                                                                                                                                                                  Ooh, I was kinda hoping that wouldn't be an issue...Scene: Monica's Apartment, everyone is there and watching a Spanish Soap on TV and are trying to figure out what is going on.]
# ...                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                ...
# 60249  (on the answering machine) Ross, hi. It's me. I just got back on the plane. And I just feel awful. That is so not how I wanted things to end with us. It's just that I wasn't expecting to see you, and all of a sudden you're there and saying these things... And... And now I'm just sitting here and thinking of all the stuff I should have said, and I didn't. I mean, I didn't even get to tell you that I love you too. Because of course I do. I love you. I love you. I love you. What am I doing? I love you! Oh, I've gotta see you. I've gotta get off this plane.
# 60259                                                                                                                                                                                                                                                                                                                                                                                                                                                                                (on the answering machine) Oh, come on, miss, isn't there any way that you can just let me off...
# 60265                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Okay. 'Cause this is where I wanna be, okay? No more messing around. I don't wanna mess this up again.
# 60271                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     If that falls off the truck, it wouldn't be the worst thing.
# 60285                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              (crying) This is harder than I thought it would be.
#
#        quote_order  season  emotion
# 16            16.0     1.0  disgust
# 20            20.0     1.0  disgust
# 28            28.0     1.0  disgust
# 34            34.0     1.0  disgust
# 51            51.0     1.0  disgust
# ...            ...     ...      ...
# 60249        544.0    10.0  disgust
# 60259        554.0    10.0  disgust
# 60265        560.0    10.0  disgust
# 60271        566.0    10.0  disgust
# 60285        580.0    10.0  disgust
#
# [4216 rows x 7 columns]

# %% [markdown]
# ## Códigos de ejemplo de clase

# %%
df["sentimiento"] = df["review"].progress_apply(analisis_sentimiento)
# Out:
# Pensando: 100%|██████████| 250/250 [00:33<00:00,  7.44it/s]

# %%
df.head()
# Out:
#        username                                                episode  \
# 0    ComedyGold            1x01 - The One Where Monica Gets a Roommate
# 1    ComedyGold                1x09 - The One Where Underdog Gets Away
# 2  TribbianiFan                     1x15 - The One with the Stoned Guy
# 3     BingWatch            1x01 - The One Where Monica Gets a Roommate
# 4   GellerPride  1x05 - The One with the East German Laundry Detergent
#
#                                                                                        review  \
# 0          Mixed feelings about this one. Certain moments was great but the pacing fell flat.
# 1       Rewatching this episode and I appreciate it more. The humor holds up remarkably well.
# 2     Rewatching this episode and I appreciate it more. The humor holds up surprisingly well.
# 3  This one missed the mark with side story. I found myself dying laughing during most of it.
# 4                 Not terrible but uneven. The performances could have been more interesting.
#
#   sentimiento
# 0    negative
# 1    positive
# 2    positive
# 3    negative
# 4    negative

# %%
df[df["sentimiento"] == "neutral"]
# Out:
#            username                                      episode  \
# 15   WeWereOnABreak                1x03 - The One with the Thumb
# 16     BuffayEnergy               1x10 - The One with the Monkey
# 44     BingeWatcher                 1x06 - The One with the Butt
# 64        BingWatch             1x07 - The One with the Blackout
# 70          RetroTV               1x10 - The One with the Monkey
# 72       HowYouDoin  1x01 - The One Where Monica Gets a Roommate
# 77      PhoebeVibes  1x02 - The One with the Sonogram at the End
# 90          RetroTV       1x16 - The One with Two Parts (Part 1)
# 105         RetroTV       1x17 - The One with Two Parts (Part 2)
# 111   RossTheGenius                1x11 - The One with Mrs. Bing
# 128     PivotMaster  1x02 - The One with the Sonogram at the End
# 130      HowYouDoin         1x08 - The One Where Nana Dies Twice
# 134       SmellyCat    1x04 - The One with George Stephanopoulos
# 144      IconicShow                1x11 - The One with Mrs. Bing
# 145     RachelLover           1x15 - The One with the Stoned Guy
# 148      PurpleDoor             1x07 - The One with the Blackout
# 161    CouchCentral      1x09 - The One Where Underdog Gets Away
# 205     LobsterLove                1x03 - The One with the Thumb
#
#                                                                                   review  \
# 15          Not bad, not great. chemistry had potential but choppy. Still decent enough.
# 16                      This one is peak for what it is. {positive} but also {negative}.
# 44                Pretty standard episode. subplot is peak but nothing earlier episodes.
# 64                         Not bad, not great. humor had potential but slow. Still fine.
# 70                Not bad, not great. writing had potential but rushed. Still watchable.
# 72             Not bad, not great. timing had potential but uneven. Still decent enough.
# 77                   Not bad, not great. chemistry had potential but rushed. Still fine.
# 90               Pretty standard episode. subplot is strongest but nothing the classics.
# 105                   Pretty standard episode. subplot is peak but nothing the classics.
# 111  Pretty standard episode. character arc is peak but nothing other season 1 episodes.
# 128               Not bad, not great. performances had potential but rushed. Still okay.
# 130                  Not bad, not great. chemistry had potential but uneven. Still fine.
# 134             Pretty standard episode. character arc is best but nothing the classics.
# 144                It has its scenes but overall passable. Some good dialogue, some not.
# 145                Not bad, not great. dialogue had potential but slow. Still watchable.
# 148        Pretty standard episode. main plot is strongest but nothing earlier episodes.
# 161              Not bad, not great. performances had potential but awkward. Still fine.
# 205     Pretty standard episode. side story is peak but nothing other season 1 episodes.
#
#     sentimiento
# 15      neutral
# 16      neutral
# 44      neutral
# 64      neutral
# 70      neutral
# 72      neutral
# 77      neutral
# 90      neutral
# 105     neutral
# 111     neutral
# 128     neutral
# 130     neutral
# 134     neutral
# 144     neutral
# 145     neutral
# 148     neutral
# 161     neutral
# 205     neutral

# %%
def score(texto):
    try:
        res = sentiment_analyzer(texto)
        return res[0]["score"]
    
    except:
        return texto

# %%
df["score"] = df["review"].progress_apply(score)
# Out:
# Pensando: 100%|██████████| 250/250 [00:30<00:00,  8.31it/s]

# %%
df.head()
# Out:
#        username                                                episode  \
# 0    ComedyGold            1x01 - The One Where Monica Gets a Roommate
# 1    ComedyGold                1x09 - The One Where Underdog Gets Away
# 2  TribbianiFan                     1x15 - The One with the Stoned Guy
# 3     BingWatch            1x01 - The One Where Monica Gets a Roommate
# 4   GellerPride  1x05 - The One with the East German Laundry Detergent
#
#                                                                                        review  \
# 0          Mixed feelings about this one. Certain moments was great but the pacing fell flat.
# 1       Rewatching this episode and I appreciate it more. The humor holds up remarkably well.
# 2     Rewatching this episode and I appreciate it more. The humor holds up surprisingly well.
# 3  This one missed the mark with side story. I found myself dying laughing during most of it.
# 4                 Not terrible but uneven. The performances could have been more interesting.
#
#   sentimiento     score
# 0    negative  0.846390
# 1    positive  0.977597
# 2    positive  0.977397
# 3    negative  0.780301
# 4    negative  0.647537

# %%
df.groupby("sentimiento")["score"].mean()
# Out:
# sentimiento
# negative    0.861661
# neutral     0.533297
# positive    0.926222
# Name: score, dtype: float64

# %%
translator = pipeline(
    "translation",
    model="Helsinki-NLP/opus-mt-en-es"
)
# Out:
# c:\Users\cesar\anaconda3\envs\promo_60\Lib\site-packages\transformers\models\marian\tokenization_marian.py:175: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Device set to use cpu

# %%
def traductor(texto):
    try:
        traduccion = translator(texto, max_length=512)[0]['translation_text']
        return traduccion
    except:
        return texto

# %%
df["review_esp"] = df["review"].progress_apply(traductor)
# Out:
# Pensando: 100%|██████████| 250/250 [05:29<00:00,  1.32s/it]

# %%
df.head()
# Out:
#        username                                                episode  \
# 0    ComedyGold            1x01 - The One Where Monica Gets a Roommate
# 1    ComedyGold                1x09 - The One Where Underdog Gets Away
# 2  TribbianiFan                     1x15 - The One with the Stoned Guy
# 3     BingWatch            1x01 - The One Where Monica Gets a Roommate
# 4   GellerPride  1x05 - The One with the East German Laundry Detergent
#
#                                                                                        review  \
# 0          Mixed feelings about this one. Certain moments was great but the pacing fell flat.
# 1       Rewatching this episode and I appreciate it more. The humor holds up remarkably well.
# 2     Rewatching this episode and I appreciate it more. The humor holds up surprisingly well.
# 3  This one missed the mark with side story. I found myself dying laughing during most of it.
# 4                 Not terrible but uneven. The performances could have been more interesting.
#
#   sentimiento     score  \
# 0    negative  0.846390
# 1    positive  0.977597
# 2    positive  0.977397
# 3    negative  0.780301
# 4    negative  0.647537
#
#                                                                                                    review_esp
# 0           Sentimientos encontrados sobre éste. Ciertos momentos fueron geniales, pero el ritmo se derrumbó.
# 1                               Rever este episodio y lo aprecio más. El humor se mantiene notablemente bien.
# 2                          Rever este episodio y lo aprecio más. El humor se mantiene sorprendentemente bien.
# 3  Este perdió la marca con la historia lateral. Me encontré muriendo de risa durante la mayor parte de ella.
# 4                                                        Las actuaciones podrían haber sido más interesantes.
